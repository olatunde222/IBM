# %% [markdown]
# C. Increate the number of epochs (5 marks)
#
# Repeat Part B but use 100 epochs this time for training.
#
# How does the mean of the mean squared errors compare to that from Step B?

# %%
#importing all the necessary libraries 
import pandas as pd 
import numpy as np 
import keras
import tensorflow as tf
from keras import layers
from keras.models import Sequential
from keras.layers import Dense
from matplotlib import pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
# Defining the path and loading the (concrete data) file using the pandas library 

path = "C:\\Users\\Windows 10 Pro\\Desktop\\python class\\IBM A-I\\concrete_data.csv"
data = pd.read_csv(path)

# %%
# Dividing the data into predictors and target for training and testing purpose
data.columns
# using the whole columns for prediction,with the exception of the [strenght] as target
predictors = data.drop(["Strength"],axis=1)
target = data["Strength"]
#spliting the data for training and testing and 0.3 represnting the 30% held for testing  
Xtrain,Xtest,Ytrain,Ytest = train_test_split(predictors,target,test_size=0.3,random_state=3)

# %%
#getting the mean of the predictors 
pred_mean = np.mean(predictors)
# Out:
# C:\Users\Windows 10 Pro\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3438: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
# subtracting the mean of thre predictor from the actual predictors 
nor_prd = predictors - pred_mean

# %%
#getting the standard diviation of the predictors 
std_predictors = np.std(predictors)

# %%
#dividing the result of the subtracted mean by the standard diviation to get the normalized predictor
normalized_predictors = nor_prd/std_predictors

# %%
# Saving the normalixed prediction and the target into x and y 
X = normalized_predictors 
Y = data["Strength"]
# passing the data for training and testing and 0.3 represnting the 30% held for testing using sklearn
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=2)

# %%
# saving the input_shape as 8 since the data has 8 attributes 
no_of_col = 8
# setting up the model 
Model = Sequential()
Model.add(Dense(10,activation="relu",input_shape=(no_of_col,)))
Model.add(Dense(1))
Model.compile(optimizer="adam",loss='mean_squared_error')

# %%
#fitting the traing and testing data into the model 
Model.fit(X_train,Y_train,validation_split=0.3,epochs=100,verbose=2)
scores = Model.evaluate(X_test, Y_test, verbose=0)
# Out:
# Epoch 1/100
# 16/16 - 0s - loss: 26.0594 - val_loss: 40.6723 - 196ms/epoch - 12ms/step
# Epoch 2/100
# 16/16 - 0s - loss: 26.0145 - val_loss: 40.6333 - 91ms/epoch - 6ms/step
# Epoch 3/100
# 16/16 - 0s - loss: 26.0760 - val_loss: 40.5805 - 94ms/epoch - 6ms/step
# Epoch 4/100
# 16/16 - 0s - loss: 26.0115 - val_loss: 40.4355 - 94ms/epoch - 6ms/step
# Epoch 5/100
# 16/16 - 0s - loss: 26.0112 - val_loss: 40.5477 - 91ms/epoch - 6ms/step
# Epoch 6/100
# 16/16 - 0s - loss: 25.9933 - val_loss: 40.5718 - 95ms/epoch - 6ms/step
# Epoch 7/100
# 16/16 - 0s - loss: 26.0429 - val_loss: 40.6665 - 92ms/epoch - 6ms/step
# Epoch 8/100
# 16/16 - 0s - loss: 26.0377 - val_loss: 40.5191 - 94ms/epoch - 6ms/step
# Epoch 9/100
# 16/16 - 0s - loss: 25.9826 - val_loss: 40.5312 - 94ms/epoch - 6ms/step
# Epoch 10/100
# 16/16 - 0s - loss: 25.9914 - val_loss: 40.6114 - 94ms/epoch - 6ms/step
# Epoch 11/100
# 16/16 - 0s - loss: 26.0063 - val_loss: 40.6692 - 94ms/epoch - 6ms/step
# Epoch 12/100
# 16/16 - 0s - loss: 25.9957 - val_loss: 40.6432 - 89ms/epoch - 6ms/step
# Epoch 13/100
# 16/16 - 0s - loss: 26.0321 - val_loss: 40.7068 - 94ms/epoch - 6ms/step
# Epoch 14/100
# 16/16 - 0s - loss: 26.0279 - val_loss: 40.5129 - 96ms/epoch - 6ms/step
# Epoch 15/100
# 16/16 - 0s - loss: 26.0179 - val_loss: 40.5747 - 92ms/epoch - 6ms/step
# Epoch 16/100
# 16/16 - 0s - loss: 26.0060 - val_loss: 40.5742 - 92ms/epoch - 6ms/step
# Epoch 17/100
# 16/16 - 0s - loss: 26.1117 - val_loss: 40.6220 - 95ms/epoch - 6ms/step
# Epoch 18/100
# 16/16 - 0s - loss: 26.0352 - val_loss: 40.5662 - 94ms/epoch - 6ms/step
# Epoch 19/100
# 16/16 - 0s - loss: 26.0318 - val_loss: 40.5499 - 89ms/epoch - 6ms/step
# Epoch 20/100
# 16/16 - 0s - loss: 25.9709 - val_loss: 40.5343 - 92ms/epoch - 6ms/step
# Epoch 21/100
# 16/16 - 0s - loss: 26.0082 - val_loss: 40.5969 - 96ms/epoch - 6ms/step
# Epoch 22/100
# 16/16 - 0s - loss: 25.9913 - val_loss: 40.5218 - 90ms/epoch - 6ms/step
# Epoch 23/100
# 16/16 - 0s - loss: 26.0195 - val_loss: 40.5358 - 96ms/epoch - 6ms/step
# Epoch 24/100
# 16/16 - 0s - loss: 26.0213 - val_loss: 40.5299 - 94ms/epoch - 6ms/step
# Epoch 25/100
# 16/16 - 0s - loss: 26.0220 - val_loss: 40.6054 - 91ms/epoch - 6ms/step
# Epoch 26/100
# 16/16 - 0s - loss: 25.9901 - val_loss: 40.6353 - 94ms/epoch - 6ms/step
# Epoch 27/100
# 16/16 - 0s - loss: 25.9870 - val_loss: 40.4882 - 93ms/epoch - 6ms/step
# Epoch 28/100
# 16/16 - 0s - loss: 26.0193 - val_loss: 40.5800 - 89ms/epoch - 6ms/step
# Epoch 29/100
# 16/16 - 0s - loss: 26.0195 - val_loss: 40.6219 - 93ms/epoch - 6ms/step
# Epoch 30/100
# 16/16 - 0s - loss: 25.9695 - val_loss: 40.5799 - 90ms/epoch - 6ms/step
# Epoch 31/100
# 16/16 - 0s - loss: 26.0284 - val_loss: 40.6239 - 119ms/epoch - 7ms/step
# Epoch 32/100
# 16/16 - 0s - loss: 25.9921 - val_loss: 40.5664 - 90ms/epoch - 6ms/step
# Epoch 33/100
# 16/16 - 0s - loss: 25.9894 - val_loss: 40.5824 - 75ms/epoch - 5ms/step
# Epoch 34/100
# 16/16 - 0s - loss: 25.9692 - val_loss: 40.5981 - 76ms/epoch - 5ms/step
# Epoch 35/100
# 16/16 - 0s - loss: 26.0365 - val_loss: 40.6469 - 75ms/epoch - 5ms/step
# Epoch 36/100
# 16/16 - 0s - loss: 25.9975 - val_loss: 40.5759 - 77ms/epoch - 5ms/step
# Epoch 37/100
# 16/16 - 0s - loss: 26.0234 - val_loss: 40.4415 - 77ms/epoch - 5ms/step
# Epoch 38/100
# 16/16 - 0s - loss: 26.0466 - val_loss: 40.6568 - 91ms/epoch - 6ms/step
# Epoch 39/100
# 16/16 - 0s - loss: 25.9689 - val_loss: 40.6810 - 76ms/epoch - 5ms/step
# Epoch 40/100
# 16/16 - 0s - loss: 26.0215 - val_loss: 40.5489 - 75ms/epoch - 5ms/step
# Epoch 41/100
# 16/16 - 0s - loss: 26.0084 - val_loss: 40.4708 - 70ms/epoch - 4ms/step
# Epoch 42/100
# 16/16 - 0s - loss: 26.0319 - val_loss: 40.6541 - 76ms/epoch - 5ms/step
# Epoch 43/100
# 16/16 - 0s - loss: 25.9856 - val_loss: 40.4927 - 69ms/epoch - 4ms/step
# Epoch 44/100
# 16/16 - 0s - loss: 25.9756 - val_loss: 40.5488 - 74ms/epoch - 5ms/step
# Epoch 45/100
# 16/16 - 0s - loss: 25.9843 - val_loss: 40.5673 - 70ms/epoch - 4ms/step
# Epoch 46/100
# 16/16 - 0s - loss: 25.9588 - val_loss: 40.5622 - 78ms/epoch - 5ms/step
# Epoch 47/100
# 16/16 - 0s - loss: 25.9705 - val_loss: 40.5928 - 73ms/epoch - 5ms/step
# Epoch 48/100
# 16/16 - 0s - loss: 26.0022 - val_loss: 40.6247 - 78ms/epoch - 5ms/step
# Epoch 49/100
# 16/16 - 0s - loss: 25.9825 - val_loss: 40.5182 - 78ms/epoch - 5ms/step
# Epoch 50/100
# 16/16 - 0s - loss: 25.9637 - val_loss: 40.4797 - 73ms/epoch - 5ms/step
# Epoch 51/100
# 16/16 - 0s - loss: 25.9721 - val_loss: 40.5976 - 71ms/epoch - 4ms/step
# Epoch 52/100
# 16/16 - 0s - loss: 25.9491 - val_loss: 40.6192 - 75ms/epoch - 5ms/step
# Epoch 53/100
# 16/16 - 0s - loss: 26.0512 - val_loss: 40.4825 - 70ms/epoch - 4ms/step
# Epoch 54/100
# 16/16 - 0s - loss: 26.0181 - val_loss: 40.7204 - 71ms/epoch - 4ms/step
# Epoch 55/100
# 16/16 - 0s - loss: 25.9918 - val_loss: 40.4376 - 66ms/epoch - 4ms/step
# Epoch 56/100
# 16/16 - 0s - loss: 25.9554 - val_loss: 40.5393 - 72ms/epoch - 4ms/step
# Epoch 57/100
# 16/16 - 0s - loss: 25.9720 - val_loss: 40.6415 - 73ms/epoch - 5ms/step
# Epoch 58/100
# 16/16 - 0s - loss: 25.9415 - val_loss: 40.5283 - 73ms/epoch - 5ms/step
# Epoch 59/100
# 16/16 - 0s - loss: 26.0158 - val_loss: 40.4431 - 71ms/epoch - 4ms/step
# Epoch 60/100
# 16/16 - 0s - loss: 25.9712 - val_loss: 40.6238 - 76ms/epoch - 5ms/step
# Epoch 61/100
# 16/16 - 0s - loss: 25.9458 - val_loss: 40.5270 - 77ms/epoch - 5ms/step
# Epoch 62/100
# 16/16 - 0s - loss: 25.9674 - val_loss: 40.5484 - 74ms/epoch - 5ms/step
# Epoch 63/100
# 16/16 - 0s - loss: 25.9813 - val_loss: 40.6210 - 80ms/epoch - 5ms/step
# Epoch 64/100
# 16/16 - 0s - loss: 25.9518 - val_loss: 40.5592 - 77ms/epoch - 5ms/step
# Epoch 65/100
# 16/16 - 0s - loss: 25.9669 - val_loss: 40.4756 - 73ms/epoch - 5ms/step
# Epoch 66/100
# 16/16 - 0s - loss: 25.9580 - val_loss: 40.6043 - 74ms/epoch - 5ms/step
# Epoch 67/100
# 16/16 - 0s - loss: 25.9969 - val_loss: 40.5573 - 73ms/epoch - 5ms/step
# Epoch 68/100
# 16/16 - 0s - loss: 25.9498 - val_loss: 40.5659 - 67ms/epoch - 4ms/step
# Epoch 69/100
# 16/16 - 0s - loss: 25.9530 - val_loss: 40.5773 - 75ms/epoch - 5ms/step
# Epoch 70/100
# 16/16 - 0s - loss: 25.9652 - val_loss: 40.6114 - 77ms/epoch - 5ms/step
# Epoch 71/100
# 16/16 - 0s - loss: 25.9697 - val_loss: 40.5367 - 79ms/epoch - 5ms/step
# Epoch 72/100
# 16/16 - 0s - loss: 25.9522 - val_loss: 40.4829 - 76ms/epoch - 5ms/step
# Epoch 73/100
# 16/16 - 0s - loss: 25.9843 - val_loss: 40.6265 - 75ms/epoch - 5ms/step
# Epoch 74/100
# 16/16 - 0s - loss: 25.9339 - val_loss: 40.5115 - 72ms/epoch - 5ms/step
# Epoch 75/100
# 16/16 - 0s - loss: 25.9418 - val_loss: 40.5004 - 82ms/epoch - 5ms/step
# Epoch 76/100
# 16/16 - 0s - loss: 25.9205 - val_loss: 40.5182 - 95ms/epoch - 6ms/step
# Epoch 77/100
# 16/16 - 0s - loss: 25.9468 - val_loss: 40.6266 - 101ms/epoch - 6ms/step
# Epoch 78/100
# 16/16 - 0s - loss: 26.0265 - val_loss: 40.5342 - 101ms/epoch - 6ms/step
# Epoch 79/100
# 16/16 - 0s - loss: 25.9160 - val_loss: 40.5419 - 92ms/epoch - 6ms/step
# Epoch 80/100
# 16/16 - 0s - loss: 25.9561 - val_loss: 40.6914 - 90ms/epoch - 6ms/step
# Epoch 81/100
# 16/16 - 0s - loss: 25.9488 - val_loss: 40.6017 - 92ms/epoch - 6ms/step
# Epoch 82/100
# 16/16 - 0s - loss: 25.9881 - val_loss: 40.5366 - 90ms/epoch - 6ms/step
# Epoch 83/100
# 16/16 - 0s - loss: 25.9447 - val_loss: 40.5784 - 88ms/epoch - 5ms/step
# Epoch 84/100
# 16/16 - 0s - loss: 25.9606 - val_loss: 40.5774 - 92ms/epoch - 6ms/step
# Epoch 85/100
# 16/16 - 0s - loss: 25.9652 - val_loss: 40.5331 - 92ms/epoch - 6ms/step
# Epoch 86/100
# 16/16 - 0s - loss: 25.9546 - val_loss: 40.5980 - 86ms/epoch - 5ms/step
# Epoch 87/100
# 16/16 - 0s - loss: 25.9847 - val_loss: 40.5921 - 85ms/epoch - 5ms/step
# Epoch 88/100
# 16/16 - 0s - loss: 25.9406 - val_loss: 40.6010 - 89ms/epoch - 6ms/step
# Epoch 89/100
# 16/16 - 0s - loss: 25.9344 - val_loss: 40.6051 - 88ms/epoch - 6ms/step
# Epoch 90/100
# 16/16 - 0s - loss: 25.9164 - val_loss: 40.5893 - 89ms/epoch - 6ms/step
# Epoch 91/100
# 16/16 - 0s - loss: 25.9917 - val_loss: 40.4809 - 91ms/epoch - 6ms/step
# Epoch 92/100
# 16/16 - 0s - loss: 25.9485 - val_loss: 40.5199 - 89ms/epoch - 6ms/step
# Epoch 93/100
# 16/16 - 0s - loss: 25.9494 - val_loss: 40.5972 - 87ms/epoch - 5ms/step
# Epoch 94/100
# 16/16 - 0s - loss: 25.9425 - val_loss: 40.5898 - 84ms/epoch - 5ms/step
# Epoch 95/100
# 16/16 - 0s - loss: 25.9106 - val_loss: 40.4793 - 90ms/epoch - 6ms/step
# Epoch 96/100
# 16/16 - 0s - loss: 26.0576 - val_loss: 40.6764 - 90ms/epoch - 6ms/step
# Epoch 97/100
# 16/16 - 0s - loss: 25.9119 - val_loss: 40.5631 - 103ms/epoch - 6ms/step
# Epoch 98/100
# 16/16 - 0s - loss: 25.9747 - val_loss: 40.4853 - 85ms/epoch - 5ms/step
# Epoch 99/100
# 16/16 - 0s - loss: 25.9489 - val_loss: 40.5680 - 94ms/epoch - 6ms/step
# Epoch 100/100
# 16/16 - 0s - loss: 25.9535 - val_loss: 40.6142 - 93ms/epoch - 6ms/step
